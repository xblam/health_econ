# %%
import pandas as pd
from pathlib import Path

# Load the raw data
path = Path("data/raw_data.csv")
df = pd.read_csv(path)

# %%
print(df.shape)
# Out:
# (8984, 298)

# %%
rename_dict = {

    # ---------------------------------------------------
    # 1997 BASELINE
    # ---------------------------------------------------
    "R0000100": "id",
    "R0536300": "1997_sex",
    "R0536401": "1997_birth_month",
    "R0536402": "1997_birth_year",
    "R1200300": "1997_region",
    "R1204500": "1997_income",
    "R1204600": "1997_income_source",
    "R1204900": "1997_poverty_ratio",
    "R1210400": "1997_msa",
    "R1217500": "1997_urban_rural",
    "R1235800": "1997_sample_type",
    "R1482600": "1997_race_ethnicity",

    # ---------------------------------------------------
    # 1998
    # ---------------------------------------------------
    "R2558800": "1998_region",
    "R2563300": "1998_income",
    "R2563500": "1998_poverty_ratio",
    "R2569500": "1998_msa",
    "R2576800": "1998_urban_rural",

    "R3989000": "1998_migrate01",
    "R3989001": "1998_migrate02",
    "R3989002": "1998_migrate03",
    "R3989003": "1998_migrate04",
    "R3989004": "1998_migrate05",
    "R3989500": "1998_migrate06",
    "R3989600": "1998_migrate07",

    # ---------------------------------------------------
    # 1999
    # ---------------------------------------------------
    "R3880300": "1999_region",
    "R3884900": "1999_income",
    "R3885100": "1999_poverty_ratio",
    "R3891500": "1999_msa",
    "R3899100": "1999_urban_rural",

    "R3961200": "1999_migrate01",
    "R3961300": "1999_migrate02",
    "R3961400": "1999_migrate03",
    "R3961500": "1999_migrate04",
    "R3961600": "1999_migrate05",
    "R3961700": "1999_migrate06",

    # ---------------------------------------------------
    # 2000 – MENTAL HEALTH + CONTROLS
    # ---------------------------------------------------
    "R4893600": "2000_nervous",
    "R4893700": "2000_calm",
    "R4893800": "2000_down",
    "R4893900": "2000_happy",
    "R4894000": "2000_depressed",

    "R5459400": "2000_region",
    "R5464100": "2000_income",
    "R5464300": "2000_poverty_ratio",
    "R5473500": "2000_msa",
    "R5484100": "2000_urban_rural",

    "R5532200": "2000_migrate01",
    "R5532300": "2000_migrate02",
    "R5532400": "2000_migrate03",
    "R5532500": "2000_migrate04",
    "R5532600": "2000_migrate05",

    # ---------------------------------------------------
    # 2001
    # ---------------------------------------------------
    "R7222400": "2001_region",
    "R7227800": "2001_income",
    "R7228000": "2001_poverty_ratio",
    "R7237200": "2001_msa",
    "R7248400": "2001_urban_rural",

    "R7273600": "2001_migrate01",
    "R7273700": "2001_migrate02",
    "R7273800": "2001_migrate03",
    "R7273900": "2001_migrate04",
    "R7274000": "2001_migrate05",
    "R7274100": "2001_migrate06",

    # ---------------------------------------------------
    # 2002 – MENTAL HEALTH + CONTROLS
    # ---------------------------------------------------
    "S0920800": "2002_nervous",
    "S0920900": "2002_calm",
    "S0921000": "2002_down",
    "S0921100": "2002_happy",
    "S0921200": "2002_depressed",

    "S1530100": "2002_migrate01",
    "S1530200": "2002_migrate02",
    "S1530300": "2002_migrate03",
    "S1530400": "2002_migrate04",
    "S1530500": "2002_migrate05",
    "S1530600": "2002_migrate06",
    "S1530700": "2002_migrate07",
    "S1530800": "2002_migrate08",
    "S1530900": "2002_migrate09",
    "S1531000": "2002_migrate10",

    "S1535500": "2002_region",
    "S1541700": "2002_income",
    "S1541900": "2002_poverty_ratio",
    "S1552500": "2002_msa",
    "S1564300": "2002_urban_rural",

    # ---------------------------------------------------
    # 2003
    # ---------------------------------------------------
    "S2000000": "2003_migrate01",
    "S2000100": "2003_migrate02",
    "S2000200": "2003_migrate03",
    "S2000300": "2003_migrate04",
    "S2000400": "2003_migrate05",
    "S2000500": "2003_migrate06",
    "S2000600": "2003_migrate07",

    "S2005400": "2003_region",
    "S2011500": "2003_income",
    "S2011700": "2003_poverty_ratio",
    "S2022300": "2003_msa",
    "S2034400": "2003_urban_rural",

    # ---------------------------------------------------
    # 2004 – MENTAL HEALTH + CONTROLS
    # ---------------------------------------------------
    "S3800000": "2004_migrate01",
    "S3800100": "2004_migrate02",
    "S3800200": "2004_migrate03",
    "S3800300": "2004_migrate04",
    "S3800400": "2004_migrate05",
    "S3800500": "2004_migrate06",
    "S3800600": "2004_migrate07",
    "S3800700": "2004_migrate08",

    "S3805700": "2004_region",
    "S3812400": "2004_income",
    "S3812500": "2004_poverty_ratio",
    "S3823200": "2004_msa",
    "S3835800": "2004_urban_rural",

    "S4681900": "2004_nervous",
    "S4682000": "2004_calm",
    "S4682100": "2004_down",
    "S4682200": "2004_happy",
    "S4682300": "2004_depressed",

    # ---------------------------------------------------
    # 2005
    # ---------------------------------------------------
    "S5400000": "2005_migrate01",
    "S5400100": "2005_migrate02",
    "S5400200": "2005_migrate03",
    "S5400300": "2005_migrate04",
    "S5400400": "2005_migrate05",
    "S5400500": "2005_migrate06",
    "S5400600": "2005_migrate07",

    "S5405600": "2005_region",
    "S5412800": "2005_income",
    "S5412900": "2005_poverty_ratio",
    "S5423200": "2005_msa",
    "S5436300": "2005_urban_rural",

    # ---------------------------------------------------
    # 2006 – MENTAL HEALTH + CONTROLS
    # ---------------------------------------------------
    "S7500000": "2006_migrate01",
    "S7500100": "2006_migrate02",
    "S7500200": "2006_migrate03",
    "S7500300": "2006_migrate04",
    "S7500400": "2006_migrate05",
    "S7500500": "2006_migrate06",
    "S7500600": "2006_migrate07",
    "S7500700": "2006_migrate08",
    "S7500800": "2006_migrate09",

    "S7506100": "2006_region",
    "S7513700": "2006_income",
    "S7513800": "2006_poverty_ratio",
    "S7525300": "2006_msa",
    "S7537100": "2006_urban_rural",

    "S8332300": "2006_nervous",
    "S8332400": "2006_calm",
    "S8332500": "2006_down",
    "S8332600": "2006_happy",
    "S8332700": "2006_depressed",

    # ---------------------------------------------------
    # 2007
    # ---------------------------------------------------
    "T0007500": "2007_migrate01",
    "T0007600": "2007_migrate02",
    "T0007700": "2007_migrate03",
    "T0007800": "2007_migrate04",
    "T0007900": "2007_migrate05",
    "T0008000": "2007_migrate06",

    "T0009400": "2007_region",
    "T0014100": "2007_income",
    "T0014200": "2007_poverty_ratio",
    "T0025600": "2007_msa",
    "T0033700": "2007_urban_rural",

    # ---------------------------------------------------
    # 2008 – MENTAL HEALTH + CONTROLS
    # ---------------------------------------------------
    "T2010500": "2008_migrate07",
    "T2010600": "2008_migrate08",
    "T2010700": "2008_migrate09",

    "T2012100": "2008_region",
    "T2016200": "2008_income",
    "T2016300": "2008_poverty_ratio",
    "T2020500": "2008_msa",
    "T2021300": "2008_urban_rural",

    "T2782600": "2008_nervous",
    "T2782700": "2008_calm",
    "T2782800": "2008_down",
    "T2782900": "2008_happy",
    "T2783000": "2008_depressed",

    # ---------------------------------------------------
    # 2009
    # ---------------------------------------------------
    "T3602100": "2009_region",
    "T3606500": "2009_income",
    "T3606600": "2009_poverty_ratio",
    "T3611200": "2009_msa",
    "T3612000": "2009_urban_rural",

    # ---------------------------------------------------
    # 2010 – MENTAL HEALTH + CONTROLS
    # ---------------------------------------------------
    "T5202300": "2010_region",
    "T5206900": "2010_income",
    "T5207000": "2010_poverty_ratio",
    "T5211600": "2010_msa",
    "T5211900": "2010_urban_rural",

    "T6143700": "2010_nervous",
    "T6143800": "2010_calm",
    "T6143900": "2010_down",
    "T6144000": "2010_happy",
    "T6144100": "2010_depressed",

    # ---------------------------------------------------
    # 2011
    # ---------------------------------------------------
    "T6652100": "2011_region",
    "T6656700": "2011_income",
    "T6656800": "2011_poverty_ratio",
    "T6663000": "2011_msa",
    "T6663300": "2011_urban_rural",

    # ---------------------------------------------------
    # 2013
    # ---------------------------------------------------
    "T8123700": "2013_region",
    "T8129100": "2013_income",
    "T8129200": "2013_poverty_ratio",
    "T8134200": "2013_msa",
    "T8134500": "2013_urban_rural",

    # ---------------------------------------------------
    # 2015 – MENTAL HEALTH + CONTROLS
    # ---------------------------------------------------
    "U0001900": "2015_region",
    "U0008900": "2015_income",
    "U0009000": "2015_poverty_ratio",
    "U0014700": "2015_msa",
    "U0015000": "2015_urban_rural",

    "U1030700": "2015_nervous",
    "U1030800": "2015_calm",
    "U1030900": "2015_down",
    "U1031000": "2015_happy",
    "U1031100": "2015_depressed",

    # ---------------------------------------------------
    # 2017 – MENTAL HEALTH + CONTROLS
    # ---------------------------------------------------
    "U1838600": "2017_region",
    "U1845500": "2017_income",
    "U1845600": "2017_poverty_ratio",
    "U1852500": "2017_msa",
    "U1853200": "2017_urban_rural",

    "U2964800": "2017_nervous",
    "U2964900": "2017_calm",
    "U2965000": "2017_down",
    "U2965100": "2017_happy",
    "U2965200": "2017_depressed",

    # ---------------------------------------------------
    # 2019 – MENTAL HEALTH + CONTROLS
    # ---------------------------------------------------
    "U3438000": "2019_region",
    "U3444000": "2019_income",
    "U3444100": "2019_poverty_ratio",
    "U3451600": "2019_msa",
    "U3453600": "2019_urban_rural",

    "U4369900": "2019_nervous",
    "U4370000": "2019_calm",
    "U4370100": "2019_down",
    "U4370200": "2019_happy",
    "U4370300": "2019_depressed",

    # ---------------------------------------------------
    # 2021 – CONTROLS ONLY
    # ---------------------------------------------------
    "U4943100": "2021_region",
    "U4949700": "2021_income",
    "U4949800": "2021_poverty_ratio",
    "U4954700": "2021_msa",
    "U4956900": "2021_urban_rural",
}
df = df.rename(columns=rename_dict)

# %%
df.head()
# Out:
#    PUBID_1997  KEY_SEX_1997  KEY_BDATE_M_1997  KEY_BDATE_Y_1997  \
# 0           1             2                 9              1981
# 1           2             1                 7              1982
# 2           3             2                 9              1983
# 3           4             2                 2              1981
# 4           5             1                10              1982
#
#    CV_CENSUS_REGION_1997  CV_INCOME_GROSS_YR_1997  CV_HH_INCOME_SOURCE_1997  \
# 0                      1                       -3                         1
# 1                      1                       -4                         1
# 2                      1                    63000                         1
# 3                      1                    11700                         1
# 4                      1                       -3                         1
#
#    CV_HH_POV_RATIO_1997  CV_MSA_1997  CV_URBAN_RURAL_1997  ...  U4942400  \
# ...

# %%
print(list(df.columns))
# Out:
# ['PUBID_1997', 'KEY_SEX_1997', 'KEY_BDATE_M_1997', 'KEY_BDATE_Y_1997', 'CV_CENSUS_REGION_1997', 'CV_INCOME_GROSS_YR_1997', 'CV_HH_INCOME_SOURCE_1997', 'CV_HH_POV_RATIO_1997', 'CV_MSA_1997', 'CV_URBAN_RURAL_1997', 'CV_SAMPLE_TYPE_1997', 'KEY_RACE_ETHNICITY_1997', 'CV_CENSUS_REGION_1998', 'CV_INCOME_GROSS_YR_1998', 'CV_HH_POV_RATIO_1998', 'CV_MSA_1998', 'CV_URBAN_RURAL_1998', 'CV_CENSUS_REGION_1999', 'CV_INCOME_GROSS_YR_1999', 'CV_HH_POV_RATIO_1999', 'CV_MSA_1999', 'CV_URBAN_RURAL_1999', 'CV_MIGRATE_01_1999', 'CV_MIGRATE_02_1999', 'CV_MIGRATE_03_1999', 'CV_MIGRATE_04_1999', 'CV_MIGRATE_05_1999', 'CV_MIGRATE_06_1999', 'CV_MIGRATE_01_1998', 'CV_MIGRATE_02_1998', 'CV_MIGRATE_03_1998', 'CV_MIGRATE_04_1998', 'CV_MIGRATE_05_1998', 'CV_MIGRATE_06_1998', 'CV_MIGRATE_07_1998', 'YSAQ_282C_2000', 'YSAQ_282D_2000', 'YSAQ_282E_2000', 'YSAQ_282F_2000', 'YSAQ_282G_2000', '2000_region', '2000_income', '2000_poverty_ratio', '2000_msa', '2000_urban_rural', '2000_migrate01', '2000_migrate02', '2000_migra
# ...
